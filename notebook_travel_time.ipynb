# %% [markdown]
# # **Finding the Shortest Travel Time by using Machine Learning and Genetic Algorithm**
#
# The purpose of this project is to find the shortest route given some locations. For that, a machine learning model is builded for predicting the travel time between each pair of locations. After that, a genetic algorithm model is used to find which sequence of locations takes the shortest time.
#
# Also, in this approach is used both continuous and categorical features. The categorical features also include information about weather. Futhermore, embedding layers are used and they learn a set of weights for each of the categorical columns.
#
# Datasets:
# 1.   [Weather data in New York City - 2016](https://www.kaggle.com/mathijs/weather-data-in-new-york-city-2016)
# 2.   [New York City Taxi Trip Duration](https://www.kaggle.com/c/nyc-taxi-trip-duration)

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline

plt.style.use('seaborn')

# %%
# Intall Cartopy and a few pre-requisites
# !apt-get install -qq libgdal-dev libproj-dev

# !apt-get -V -y -qq install python-cartopy python3-cartopy

# !pip uninstall shapely -y

# !pip install shapely --no-binary shapely

# %% [markdown]
# **Loading and Visualizing the Data**

# %%
weather = pd.read_csv("weather.csv") 
train = pd.read_csv("train.csv")[:100000]

# %%
print(train.shape)
train.head()
# Out:
# (100000, 11)
#           id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0  id2875421          2  2016-03-14 17:24:55  2016-03-14 17:32:30
# 1  id2377394          1  2016-06-12 00:43:35  2016-06-12 00:54:38
# 2  id3858529          2  2016-01-19 11:35:24  2016-01-19 12:10:48
# 3  id3504673          2  2016-04-06 19:32:31  2016-04-06 19:39:40
# 4  id2181028          2  2016-03-26 13:30:55  2016-03-26 13:38:10
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.982155        40.767937         -73.964630
# 1                1        -73.980415        40.738564         -73.999481
# 2                1        -73.979027        40.763939         -74.005333
# 3                1        -74.010040        40.719971         -74.012268
# 4                1        -73.973053        40.793209         -73.972923
#
#    dropoff_latitude store_and_fwd_flag  trip_duration
# 0         40.765602                  N            455
# 1         40.731152                  N            663
# 2         40.710087                  N           2124
# 3         40.706718                  N            429
# 4         40.782520                  N            435

# %%
# Plot pickup and dropff's localizations
import cartopy.crs as ccrs
import cartopy
import cartopy.feature as cfeature
import numpy as np

extent = [-74.7, -73.1, 40.3, 41.2]

# Pickup

ax = plt.subplot(1, 2, 1)
ax = plt.axes(projection=ccrs.AlbersEqualArea())
ax.set_extent(extent)

ax.add_feature(cartopy.feature.OCEAN)
ax.add_feature(cartopy.feature.LAND, edgecolor='black')
ax.add_feature(cartopy.feature.LAKES, edgecolor='black')
ax.add_feature(cartopy.feature.RIVERS)
lon = train.pickup_longitude
lat = train.pickup_latitude


ax.plot(lon, lat, 'r.', transform=ccrs.PlateCarree(), zorder=2, label='Pickup')
ax.coastlines(resolution='10m')
ax.legend()
plt.show()

# Dropoff
ax = plt.subplot(1, 2, 2)
ax = plt.axes(projection=ccrs.AlbersEqualArea())
ax.set_extent(extent)

ax.add_feature(cartopy.feature.OCEAN)
ax.add_feature(cartopy.feature.LAND, edgecolor='black')
ax.add_feature(cartopy.feature.LAKES, edgecolor='black')
ax.add_feature(cartopy.feature.RIVERS)
lon = train.dropoff_longitude
lat = train.dropoff_latitude

ax.plot(lon, lat, 'b.', transform=ccrs.PlateCarree(), zorder=2, label='Dropoff')
ax.coastlines(resolution='10m')
ax.legend()
plt.show()
# Out:
# /usr/lib/python3/dist-packages/cartopy/io/__init__.py:264: DownloadWarning: Downloading: http://naciscdn.org/naturalearth/110m/physical/ne_110m_ocean.zip
#   warnings.warn('Downloading: {}'.format(url), DownloadWarning)
# /usr/lib/python3/dist-packages/cartopy/io/__init__.py:264: DownloadWarning: Downloading: http://naciscdn.org/naturalearth/110m/physical/ne_110m_land.zip
#   warnings.warn('Downloading: {}'.format(url), DownloadWarning)
# /usr/lib/python3/dist-packages/cartopy/io/__init__.py:264: DownloadWarning: Downloading: http://naciscdn.org/naturalearth/110m/physical/ne_110m_lakes.zip
#   warnings.warn('Downloading: {}'.format(url), DownloadWarning)
# /usr/lib/python3/dist-packages/cartopy/io/__init__.py:264: DownloadWarning: Downloading: http://naciscdn.org/naturalearth/110m/physical/ne_110m_rivers_lake_centerlines.zip
#   warnings.warn('Downloading: {}'.format(url), DownloadWarning)
# /usr/lib/python3/dist-packages/cartopy/io/__init__.py:264: DownloadWarning: Downloading: http://naciscdn.org/naturalearth/10m/physical/ne_10m_coastline.zip
#   warnings.warn('Downloading: {}'.format(url), DownloadWarning)

# %%
# Search nulls and percentage of them
def check_null(df):
    total = df.isnull().sum().sort_values(ascending=False)
    percent_1 = df.isnull().sum()/df.isnull().count()*100
    percent_2 = (round(percent_1, 1)).sort_values(ascending=False)
    missing_data = pd.concat([total, percent_2], axis=1, keys=['Total', '%'])
    print(missing_data.head(5))

check_null(train)
# Out:
#                     Total    %
# trip_duration           0  0.0
# store_and_fwd_flag      0  0.0
# dropoff_latitude        0  0.0
# dropoff_longitude       0  0.0
# pickup_latitude         0  0.0

# %% [markdown]
# **Preparing the Data**

# %%
# Create attributes in weather dataset
from sklearn.preprocessing import OrdinalEncoder
ordinal_encoder = OrdinalEncoder(dtype=np.int32)

weather.Time = pd.to_datetime(weather.Time)
weather = weather[weather.Time.dt.year == 2016]

weather.Conditions = ordinal_encoder.fit_transform(np.array(weather.Conditions).reshape(-1, 1))

weather["pickup_month"] = weather.Time.dt.month
weather["pickup_day"] = weather.Time.dt.day
weather["pickup_hour"] = weather.Time.dt.hour

weather.head()
# Out:
#                   Time  Temp.  Windchill  Heat Index  Humidity  Pressure  \
# 22 2016-01-01 00:00:00    5.6        3.2         NaN      0.58    1018.8
# 23 2016-01-01 01:00:00    5.6        4.0         NaN      0.53    1018.5
# 24 2016-01-01 02:00:00    5.6        4.0         NaN      0.51    1017.9
# 25 2016-01-01 03:00:00    5.0        3.9         NaN      0.53    1017.8
# 26 2016-01-01 04:00:00    5.0        3.3         NaN      0.55    1017.7
#
#     Dew Point  Visibility  Wind Dir  Wind Speed  Gust Speed  Precip Events  \
# 22       -2.2        16.1       WNW        11.1         0.0     0.0   None
# 23       -3.3        16.1  Variable         7.4         0.0     0.0   None
# 24       -3.9        16.1  Variable         7.4         0.0     0.0   None
# 25       -3.9        16.1  Variable         5.6         0.0     0.0   None
# 26       -3.3        16.1      West         7.4         0.0     0.0   None
#
#     Conditions  pickup_month  pickup_day  pickup_hour
# 22          10             1           1            0
# 23          10             1           1            1
# 24          10             1           1            2
# 25          10             1           1            3
# 26          10             1           1            4

# %%
# Remove outliers in train
old_len = len(train)
train = train[(train.trip_duration >= np.percentile(train.trip_duration, 0.99)) &
              (train.trip_duration <= np.percentile(train.trip_duration, 99.99))]
print("Removed {} outliers".format(old_len - len(train)))
# Out:
# Removed 197 outliers

# %%
# Calculate distance by using picup and dropoff's latitude and longitude
from geopy import distance

train['distance']  = train.apply(lambda row: distance.geodesic((row['dropoff_latitude'],row['dropoff_longitude']), 
                                        (row['pickup_latitude'], row['pickup_longitude'])).km, axis=1)

train.head()
# Out:
#           id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0  id2875421          2  2016-03-14 17:24:55  2016-03-14 17:32:30
# 1  id2377394          1  2016-06-12 00:43:35  2016-06-12 00:54:38
# 2  id3858529          2  2016-01-19 11:35:24  2016-01-19 12:10:48
# 3  id3504673          2  2016-04-06 19:32:31  2016-04-06 19:39:40
# 4  id2181028          2  2016-03-26 13:30:55  2016-03-26 13:38:10
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.982155        40.767937         -73.964630
# 1                1        -73.980415        40.738564         -73.999481
# 2                1        -73.979027        40.763939         -74.005333
# 3                1        -74.010040        40.719971         -74.012268
# 4                1        -73.973053        40.793209         -73.972923
#
#    dropoff_latitude store_and_fwd_flag  trip_duration  distance
# 0         40.765602                  N            455  1.502172
# 1         40.731152                  N            663  1.808660
# 2         40.710087                  N           2124  6.379687
# 3         40.706718                  N            429  1.483632
# 4         40.782520                  N            435  1.187038

# %%
# Convert to datetime
train.pickup_datetime = pd.to_datetime(train.pickup_datetime)
train.dropoff_datetime = pd.to_datetime(train.dropoff_datetime)

# Generate some attributes related to time
train['pickup_minute_of_the_day'] = train.pickup_datetime.dt.hour*60 + train.pickup_datetime.dt.minute
train["pickup_month"] = train.pickup_datetime.dt.month
train["pickup_day"] = train.pickup_datetime.dt.day
train["pickup_hour"] = train.pickup_datetime.dt.hour
train['weekday'] = train.pickup_datetime.dt.weekday

train = pd.merge(train, weather[['pickup_month', 'pickup_day', 'pickup_hour','Conditions']], how = 'left', on = ['pickup_month', 'pickup_day', 'pickup_hour'])

# Remove some samples whose datetime doesn't match 
train = train.dropna(subset=["Conditions"])

train.head()
# Out:
#           id  vendor_id     pickup_datetime    dropoff_datetime  \
# 0  id2875421          2 2016-03-14 17:24:55 2016-03-14 17:32:30
# 1  id2377394          1 2016-06-12 00:43:35 2016-06-12 00:54:38
# 2  id3858529          2 2016-01-19 11:35:24 2016-01-19 12:10:48
# 3  id3504673          2 2016-04-06 19:32:31 2016-04-06 19:39:40
# 4  id2181028          2 2016-03-26 13:30:55 2016-03-26 13:38:10
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.982155        40.767937         -73.964630
# 1                1        -73.980415        40.738564         -73.999481
# 2                1        -73.979027        40.763939         -74.005333
# 3                1        -74.010040        40.719971         -74.012268
# 4                1        -73.973053        40.793209         -73.972923
#
#    dropoff_latitude store_and_fwd_flag  trip_duration  distance  \
# 0         40.765602                  N            455  1.502172
# 1         40.731152                  N            663  1.808660
# 2         40.710087                  N           2124  6.379687
# 3         40.706718                  N            429  1.483632
# 4         40.782520                  N            435  1.187038
#
#    pickup_minute_of_the_day  pickup_month  pickup_day  pickup_hour  weekday  \
# 0                      1044             3          14           17        0
# 1                        43             6          12            0        6
# 2                       695             1          19           11        1
# 3                      1172             4           6           19        2
# 4                       810             3          26           13        5
#
#    Conditions
# 0        10.0
# 1        15.0
# 2         0.0
# 3         0.0
# 4         0.0

# %% [markdown]
# **Preparing sets**

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(train, train['trip_duration'], test_size=0.01, random_state=42)

# %%
X_train_continuous = X_train[['pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude', 'distance', 'pickup_minute_of_the_day']]
X_train_categorical = X_train[['pickup_month', 'weekday', 'Conditions']]

X_test_continuous = X_test[['pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude', 'distance', 'pickup_minute_of_the_day']]
X_test_categorical = X_test[['pickup_month', 'weekday', 'Conditions']]

X_train_continuous.head()
# Out:
#        pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 79210        -73.955002        40.783379         -73.969261         40.754101
# 43171        -73.988998        40.736580         -73.976379         40.735241
# 54887        -73.982788        40.730694         -73.990898         40.730732
# 50599        -73.953773        40.767002         -73.913940         40.714264
# 70310        -73.991493        40.756428         -73.979263         40.756561
#
#        distance  pickup_minute_of_the_day
# 79210  3.467017                       911
# 43171  1.076250                       802
# 54887  0.685123                       880
# 50599  6.754141                      1330
# 70310  1.032851                       341

# %%
# Feature scaling
from sklearn import preprocessing

scaler = preprocessing.StandardScaler().fit(X_train_continuous)
X_train_continuous = scaler.transform(X_train_continuous)

X_test_continuous = scaler.transform(X_test_continuous)

# %% [markdown]
# **Training the model**

# %%
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Flatten, Embedding, Dense, Activation, Input, concatenate, Reshape, Dropout

# %%
emb_dim = 3  # dimension of the emdedding vectors

# input_dim correponds to the number of possible categories + 1
input0 = Input(shape=(1,))
model0 = Embedding(input_dim=X_train_categorical['pickup_month'].value_counts().size+1,output_dim=emb_dim)(input0)
model0 = Flatten()(model0)

input1 = Input(shape=(1,))
model1 = Embedding(input_dim=X_train_categorical['weekday'].value_counts().size+1, output_dim=emb_dim)(input1)
model1 = Flatten()(model1)

input2 = Input(shape=(1,))
model2 = Embedding(input_dim=X_train_categorical['Conditions'].value_counts().size+3, output_dim=emb_dim)(input2)
model2 = Flatten()(model2)

continuous_input = Input(shape=(X_train_continuous.shape[1], ))

conc_model = concatenate([continuous_input,model0, model1, model2])
dense_model = Dense(units=100, activation='relu')(conc_model)
dense_model = Dropout(0.25)(dense_model)
dense_model = Dense(units=100, activation='relu')(dense_model)
out_model = Dense(units=1)(dense_model)

model = Model(inputs=[continuous_input,input0, input1, input2], outputs=out_model)
sgd = SGD(lr=0.1)
model.compile(optimizer='adam', loss="mean_absolute_error", metrics=["mean_absolute_error"])

history = model.fit([X_train_continuous, np.array(X_train_categorical['pickup_month']), np.array(X_train_categorical['weekday']), np.array(X_train_categorical['Conditions'])], 
          y_train, epochs=50, validation_split = 0.2)
# Out:
# Epoch 1/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 336.4306 - mean_absolute_error: 336.4294 - val_loss: 275.3238 - val_mean_absolute_error: 275.3867
# Epoch 2/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 281.4124 - mean_absolute_error: 281.4199 - val_loss: 261.0851 - val_mean_absolute_error: 261.1645
# Epoch 3/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 272.1284 - mean_absolute_error: 272.1252 - val_loss: 254.5921 - val_mean_absolute_error: 254.6801
# Epoch 4/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 264.7799 - mean_absolute_error: 264.7808 - val_loss: 247.1183 - val_mean_absolute_error: 247.1987
# Epoch 5/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 260.3169 - mean_absolute_error: 260.3199 - val_loss: 243.0368 - val_mean_absolute_error: 243.1207
# Epoch 6/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 256.5327 - mean_absolute_error: 256.5222 - val_loss: 239.0750 - val_mean_absolute_error: 239.1653
# Epoch 7/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 253.4337 - mean_absolute_error: 253.4330 - val_loss: 236.4426 - val_mean_absolute_error: 236.5177
# Epoch 8/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 250.7659 - mean_absolute_error: 250.7715 - val_loss: 234.0928 - val_mean_absolute_error: 234.1569
# Epoch 9/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 248.9491 - mean_absolute_error: 248.9540 - val_loss: 231.8789 - val_mean_absolute_error: 231.9519
# Epoch 10/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 248.1514 - mean_absolute_error: 248.1431 - val_loss: 231.3850 - val_mean_absolute_error: 231.4624
# Epoch 11/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 247.4475 - mean_absolute_error: 247.4536 - val_loss: 230.1476 - val_mean_absolute_error: 230.2210
# Epoch 12/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 246.6868 - mean_absolute_error: 246.6877 - val_loss: 229.7987 - val_mean_absolute_error: 229.8775
# Epoch 13/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 245.5452 - mean_absolute_error: 245.5517 - val_loss: 229.4377 - val_mean_absolute_error: 229.5092
# Epoch 14/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 245.1742 - mean_absolute_error: 245.1789 - val_loss: 228.1105 - val_mean_absolute_error: 228.1682
# Epoch 15/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 244.1557 - mean_absolute_error: 244.1462 - val_loss: 228.7641 - val_mean_absolute_error: 228.8261
# Epoch 16/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 243.3300 - mean_absolute_error: 243.3353 - val_loss: 225.6223 - val_mean_absolute_error: 225.6780
# Epoch 17/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 242.7677 - mean_absolute_error: 242.7698 - val_loss: 225.3872 - val_mean_absolute_error: 225.4494
# Epoch 18/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 241.6311 - mean_absolute_error: 241.6294 - val_loss: 226.3509 - val_mean_absolute_error: 226.4198
# Epoch 19/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 242.0122 - mean_absolute_error: 242.0091 - val_loss: 225.1766 - val_mean_absolute_error: 225.2421
# Epoch 20/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 241.5564 - mean_absolute_error: 241.5536 - val_loss: 225.0893 - val_mean_absolute_error: 225.1520
# Epoch 21/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 240.9533 - mean_absolute_error: 240.9524 - val_loss: 224.7293 - val_mean_absolute_error: 224.7944
# Epoch 22/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 240.3995 - mean_absolute_error: 240.3994 - val_loss: 224.0967 - val_mean_absolute_error: 224.1618
# Epoch 23/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 240.2401 - mean_absolute_error: 240.2439 - val_loss: 224.7831 - val_mean_absolute_error: 224.8502
# Epoch 24/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 240.1810 - mean_absolute_error: 240.1839 - val_loss: 222.6394 - val_mean_absolute_error: 222.7060
# Epoch 25/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 239.8695 - mean_absolute_error: 239.8741 - val_loss: 222.8483 - val_mean_absolute_error: 222.9202
# Epoch 26/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 239.7279 - mean_absolute_error: 239.7331 - val_loss: 226.8771 - val_mean_absolute_error: 226.9453
# Epoch 27/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 239.2426 - mean_absolute_error: 239.2477 - val_loss: 223.5096 - val_mean_absolute_error: 223.5801
# Epoch 28/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 239.2454 - mean_absolute_error: 239.2422 - val_loss: 224.7277 - val_mean_absolute_error: 224.8004
# Epoch 29/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 239.2010 - mean_absolute_error: 239.2045 - val_loss: 222.8250 - val_mean_absolute_error: 222.8860
# Epoch 30/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 238.4476 - mean_absolute_error: 238.4476 - val_loss: 221.9349 - val_mean_absolute_error: 222.0037
# Epoch 31/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 238.1307 - mean_absolute_error: 238.1246 - val_loss: 223.4610 - val_mean_absolute_error: 223.5259
# Epoch 32/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 238.1312 - mean_absolute_error: 238.1284 - val_loss: 221.7261 - val_mean_absolute_error: 221.7896
# Epoch 33/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 238.0654 - mean_absolute_error: 237.9422 - val_loss: 221.5165 - val_mean_absolute_error: 221.5730
# Epoch 34/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 237.8539 - mean_absolute_error: 237.8630 - val_loss: 221.1386 - val_mean_absolute_error: 221.2108
# Epoch 35/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 237.4836 - mean_absolute_error: 237.4883 - val_loss: 221.6471 - val_mean_absolute_error: 221.7063
# Epoch 36/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 237.0167 - mean_absolute_error: 237.0166 - val_loss: 224.3797 - val_mean_absolute_error: 224.4435
# Epoch 37/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 236.5618 - mean_absolute_error: 236.5619 - val_loss: 220.6045 - val_mean_absolute_error: 220.6687
# Epoch 38/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 236.3588 - mean_absolute_error: 236.3646 - val_loss: 219.1475 - val_mean_absolute_error: 219.2142
# Epoch 39/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 236.1831 - mean_absolute_error: 236.1832 - val_loss: 218.4221 - val_mean_absolute_error: 218.4906
# Epoch 40/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 235.5296 - mean_absolute_error: 235.5312 - val_loss: 220.6395 - val_mean_absolute_error: 220.7118
# Epoch 41/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 235.4702 - mean_absolute_error: 235.4656 - val_loss: 218.8313 - val_mean_absolute_error: 218.8997
# Epoch 42/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 235.0480 - mean_absolute_error: 235.0458 - val_loss: 217.1345 - val_mean_absolute_error: 217.2071
# Epoch 43/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 234.5767 - mean_absolute_error: 234.5777 - val_loss: 217.7346 - val_mean_absolute_error: 217.8058
# Epoch 44/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 234.3638 - mean_absolute_error: 234.3721 - val_loss: 216.9263 - val_mean_absolute_error: 216.9963
# Epoch 45/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 234.4662 - mean_absolute_error: 234.4591 - val_loss: 217.0254 - val_mean_absolute_error: 217.0932
# Epoch 46/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 234.2695 - mean_absolute_error: 234.2712 - val_loss: 218.0737 - val_mean_absolute_error: 218.1481
# Epoch 47/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 233.7097 - mean_absolute_error: 233.7115 - val_loss: 216.6775 - val_mean_absolute_error: 216.7511
# Epoch 48/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 233.7750 - mean_absolute_error: 233.7736 - val_loss: 215.8519 - val_mean_absolute_error: 215.9214
# Epoch 49/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 233.1292 - mean_absolute_error: 233.1346 - val_loss: 215.6884 - val_mean_absolute_error: 215.7532
# Epoch 50/50
# 2450/2450 [==============================] - 5s 2ms/step - loss: 233.4409 - mean_absolute_error: 233.4492 - val_loss: 217.4489 - val_mean_absolute_error: 217.5064

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 1, 3)         21          input_1[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 1, 3)         24          input_2[0][0]
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 1, 3)         51          input_3[0][0]
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 6)]          0
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 3)            0           embedding[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 3)            0           embedding_1[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 3)            0           embedding_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 15)           0           input_4[0][0]
#                                                                  flatten[0][0]
#                                                                  flatten_1[0][0]
#                                                                  flatten_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 100)          1600        concatenate[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 100)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 100)          10100       dropout[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            101         dense_1[0][0]
# ==================================================================================================
# Total params: 11,897
# Trainable params: 11,897
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(
    model, to_file='model.png', show_shapes=False, show_layer_names=True,
    rankdir='TB', expand_nested=False, dpi=96
)

# %% [markdown]
# **Checking the trained model**

# %%
# Plot loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
# Test some samples from test dataset
df_test = pd.DataFrame(data={'trip_duration':y_test[0:10].copy()})

df_test['pred'] = model.predict([X_test_continuous[0:10], np.array(X_test_categorical['pickup_month'])[0:10], 
               np.array(X_test_categorical['weekday'])[0:10], np.array(X_test_categorical['Conditions'])[0:10]]).astype('int32')
df_test['%diff'] = 100 * (df_test['pred'] / df_test['trip_duration'])

df_test.sort_values("%diff", ascending=False)
# Out:
#        trip_duration  pred       %diff
# 1063             152   438  288.157895
# 58818            431   653  151.508121
# 14645            292   431  147.602740
# 97043            387   568  146.770026
# 43679           1906  2314  121.406086
# 56193            784   862  109.948980
# 47460           1241  1248  100.564061
# 40534            288   283   98.263889
# 59389            398   276   69.346734
# 47946           1360   923   67.867647

# %%
# Calculate distance between categoricals from embedding
from scipy import spatial

keras_embs0 = model.layers[3].get_weights()[0] 
keras_embs1 = model.layers[4].get_weights()[0] 

spatial.distance.cosine(keras_embs0[2], keras_embs1[3])
# Out:
# 0.29585498571395874

# %% [markdown]
# **Finding shortest path**

# %%
# Install deap library to create the GA model
# !pip install deap
# Out:
# Collecting deap
#   Downloading https://files.pythonhosted.org/packages/0a/eb/2bd0a32e3ce757fb26264765abbaedd6d4d3640d90219a513aeabd08ee2b/deap-1.3.1-cp36-cp36m-manylinux2010_x86_64.whl (157kB)
#      |████████████████████████████████| 163kB 4.9MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from deap) (1.18.2)
# Installing collected packages: deap
# Successfully installed deap-1.3.1

# %%
np.random.seed(0) 
np.random.rand(0)

# Get locations 
locations_count = 8
indices = list(np.random.randint(0, X_test.shape[0], size=locations_count))
locations_coord = {}

# Get locations' coordinates 
for i in range(len(indices)):
  locations_coord[i] = [X_test.iloc[indices[i]]['pickup_longitude'], X_test.iloc[indices[i]]['pickup_latitude']] 

# Get the categorical attributes
# Those categorical attributes are fixed among the locations used in GA
trip_month = [X_test_categorical.iloc[indices[0]]['pickup_month']]
trip_weekday = [X_test_categorical.iloc[indices[0]]['weekday']]
trip_weather = [X_test_categorical.iloc[indices[0]]['Conditions']]

# Get minute of the day in which the driver starts his trip 
# by using the first location selected in random
start_minute_of_the_day = X_test.iloc[indices[0]]['pickup_minute_of_the_day']

locations_coord
# Out:
# {0: [-74.00312042236328, 40.733192443847656],
#  1: [-73.98365020751955, 40.721595764160156],
#  2: [-73.98960876464844, 40.74411010742188],
#  3: [-73.98342895507811, 40.764961242675774],
#  4: [-73.9837875366211, 40.73842239379883],
#  5: [-73.95428466796875, 40.78401184082031],
#  6: [-73.95828247070312, 40.80311965942383],
#  7: [-73.9733123779297, 40.76422500610352]}

# %%
# Prepare function to calculate total duration of an indivudual

def evalOneMin(individual):
    total_duration = 0
    current_minute_of_the_day = start_minute_of_the_day
    for i in range(0, len(individual)-1):
        # It should avoid repeating the pathes in individual
        if individual.count(individual[i]) > 1:
            return 99999,
            
        trip_distance = distance.geodesic((locations_coord[individual[i+1]][1], locations_coord[individual[i+1]][0]), 
                                     (locations_coord[individual[i]][1], locations_coord[individual[i]][0])).km

        continuous_sample = scaler.transform([[locations_coord[individual[i]][0], locations_coord[individual[i]][1],
                                   locations_coord[individual[i+1]][0], locations_coord[individual[i+1]][1],
                                   trip_distance, current_minute_of_the_day]])
        
        duration = model.predict([np.array(continuous_sample), np.array(trip_month), np.array(trip_weekday), np.array(trip_weather)])
        
        # current_minute_of_the_day is increased for each pair of location traveled 
        current_minute_of_the_day += int(duration/60)
        total_duration += duration
      
      
    return total_duration,

# %%
# GA initializers
import array
import random

from deap import algorithms
from deap import base
from deap import creator
from deap import tools


# Weights is -1 because I want a fitness score as low as possible
creator.create("FitnessMax", base.Fitness, weights=(-1.0,))
creator.create("Individual", array.array, typecode='b', fitness=creator.FitnessMax)

toolbox = base.Toolbox()

# Attribute generator: generates chromosomes that vary from 0 to (locations_count-1)
toolbox.register("attr_num", random.randint, 0, locations_count-1)

# Structure initializers
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_num, locations_count)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

toolbox.register("evaluate", evalOneMin)
toolbox.register("mate", tools.cxTwoPoint)
toolbox.register("mutate", tools.mutFlipBit, indpb=0.05)
toolbox.register("select", tools.selTournament, tournsize=3)

# %%
# Execute evolution 

random.seed(0)

pop = toolbox.population(n=200)
hof = tools.HallOfFame(1)
stats = tools.Statistics(lambda ind: ind.fitness.values)
stats.register("avg", np.mean)
stats.register("std", np.std)
stats.register("min", np.min)
stats.register("max", np.max)

pop, log = algorithms.eaSimple(pop, toolbox, cxpb=0.5, mutpb=0.1, ngen=30, 
                                stats=stats, halloffame=hof, verbose=True)

pop, log, hof
# Out:
# gen	nevals	avg         	std         	min          	max
# 0  	200   	[[99528.04]]	[[6645.781]]	[[5777.7236]]	99999
# 1  	104   	[[98585.82]]	[[11452.82]]	[[5777.7236]]	99999
# 2  	108   	[[97170.6]] 	[[16083.704]]	[[5313.1553]]	99999
# 3  	123   	[[96699.06]]	[[17328.217]]	[[5313.1553]]	99999
# 4  	94    	[[94343.5]] 	[[22385.518]]	[[5313.1553]]	99999
# 5  	95    	[[86328.96]]	[[33194.85]] 	[[5111.628]] 	99999
# 6  	117   	[[77371.086]]	[[40266.76]] 	[[5111.628]] 	99999
# 7  	110   	[[63707.703]]	[[45868.008]]	[[5111.628]] 	99999
# 8  	105   	[[42500.67]] 	[[45975.117]]	[[5111.628]] 	99999
# 9  	116   	[[32125.91]] 	[[42326.41]] 	[[5111.628]] 	99999
# 10 	106   	[[25502.188]]	[[38409.3]]  	[[5111.628]] 	99999
# 11 	132   	[[35361.35]] 	[[43832.637]]	[[5111.628]] 	99999
# 12 	106   	[[33889.184]]	[[43279.32]] 	[[5111.628]] 	99999
# 13 	104   	[[23426.703]]	[[37086.03]] 	[[5111.628]] 	99999
# 14 	104   	[[30433.775]]	[[41770.996]]	[[5111.628]] 	99999
# 15 	106   	[[33647.15]] 	[[43437.703]]	[[5111.628]] 	99999
# 16 	111   	[[14617.897]]	[[28460.482]]	[[5111.628]] 	99999
# 17 	113   	[[7959.2544]]	[[16186.397]]	[[5111.628]] 	99999
# 18 	103   	[[7958.247]] 	[[16186.565]]	[[5111.628]] 	99999
# 19 	116   	[[9855.994]] 	[[20680.227]]	[[5111.628]] 	99999
# 20 	100   	[[7009.373]] 	[[13284.221]]	[[5111.628]] 	99999
# 21 	126   	[[6534.936]] 	[[11533.783]]	[[5111.628]] 	99999
# 22 	102   	[[10804.875]]	[[22534.502]]	[[5111.628]] 	99999
# 23 	98    	[[7483.81]]  	[[14814.297]]	[[5111.628]] 	99999
# 24 	100   	[[7958.247]] 	[[16186.552]]	[[5111.628]] 	99999
# 25 	117   	[[7958.246]] 	[[16186.557]]	[[5111.628]] 	99999
# 26 	104   	[[7958.246]] 	[[16186.549]]	[[5111.628]] 	99999
# 27 	114   	[[9381.558]] 	[[19670.533]]	[[5111.628]] 	99999
# 28 	117   	[[6534.936]] 	[[11533.785]]	[[5111.628]] 	99999
# 29 	132   	[[7483.81]]  	[[14814.3]]  	[[5111.628]] 	99999
# 30 	125   	[[8432.684]] 	[[17438.389]]	[[5111.628]] 	99999
# ([array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 1, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 0, 6, 0, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 1, 0, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 0, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 1, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 0, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 1, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5]),
#   array('b', [4, 2, 0, 7, 3, 6, 1, 5])],
#  [{'avg': array([[99528.04]], dtype=float32),
#    'gen': 0,
#    'max': 99999.0,
#    'min': array([[5777.7236]], dtype=float32),
#    'nevals': 200,
#    'std': array([[6645.781]], dtype=float32)},
#   {'avg': array([[98585.82]], dtype=float32),
#    'gen': 1,
#    'max': 99999.0,
#    'min': array([[5777.7236]], dtype=float32),
#    'nevals': 104,
#    'std': array([[11452.82]], dtype=float32)},
#   {'avg': array([[97170.6]], dtype=float32),
#    'gen': 2,
#    'max': 99999.0,
#    'min': array([[5313.1553]], dtype=float32),
#    'nevals': 108,
#    'std': array([[16083.704]], dtype=float32)},
#   {'avg': array([[96699.06]], dtype=float32),
#    'gen': 3,
#    'max': 99999.0,
#    'min': array([[5313.1553]], dtype=float32),
#    'nevals': 123,
#    'std': array([[17328.217]], dtype=float32)},
#   {'avg': array([[94343.5]], dtype=float32),
#    'gen': 4,
#    'max': 99999.0,
#    'min': array([[5313.1553]], dtype=float32),
#    'nevals': 94,
#    'std': array([[22385.518]], dtype=float32)},
#   {'avg': array([[86328.96]], dtype=float32),
#    'gen': 5,
#    'max': 99999.0,
#    'min': array([[5111.628]], dtype=float32),
#    'nevals': 95,
#    'std': array([[33194.85]], dtype=float32)},
#   {'avg': array([[77371.086]], dtype=float32),
#    'gen': 6,
#    'max': 99999.0,
#    'min': array([[5111.628]], dtype=float32),
#    'nevals': 117,
#    'std': array([[40266.76]], dtype=float32)},
#   {'avg': array([[63707.703]], dtype=float32),
#    'gen': 7,
#    'max': 99999.0,
#    'min': array([[5111.628]], dtype=float32),
#    'nevals': 110,
#    'std': array([[45868.008]], dtype=float32)},
#   {'avg': array([[42500.67]], dtype=float32),
#    'gen': 8,
#    'max': 99999.0,
#    'min': array([[5111.628]], dtype=float32),
#    'nevals': 105,
#    'std': array([[45975.117]], dtype=float32)},
#   {'avg': array([[32125.91]], dtype=float32),
#    'gen': 9,
#    'max': 99999.0,
#    'min': array([[5111.628]], dtype=float32),
#    'nevals': 116,
#    'std': array([[42326.41]], dtype=float32)},
#   {'avg': array([[25502.188]], dtype=float32),
#    'gen': 10,
#    'max': 99999.0,
#    'min': array([[5111.628]], dtype=float32),
#    'nevals': 106,
#    'std': array([[38409.3]], dtype=float32)},
#   {'avg': array([[35361.35]], dtype=float32),
#    'gen': 11,
#    'max': 99999.0,
#    'min': array([[5111.628]], dtype=float32),
#    'nevals': 132,
#    'std': array([[43832.637]], dtype=float32)},
#   {'avg': array([[33889.184]], dtype=float32),
#    'gen': 12,
#    'max': 99999.0,
#    'min': array([[5111.628]], dtype=float32),
#    'nevals': 106,
#    'std': array([[43279.32]], dtype=float32)},
#   {'avg': array([[23426.703]], dtype=float32),
#    'gen': 13,
#    'max': 99999.0,
#    'min': array([[5111.628]], dtype=float32),
#    'nevals': 104,
#    'std': array([[37086.03]], dtype=float32)},
#   {'avg': array([[30433.775]], dtype=float32),
#    'gen': 14,
#    'max': 99999.0,
#    'min': array([[5111.628]], dtype=float32),
#    'nevals': 104,
#    'std': array([[41770.996]], dtype=float32)},
#   {'avg': array([[33647.15]], dtype=float32),
#    'gen': 15,
#    'max': 99999.0,
#    'min': array([[5111.628]], dtype=float32),
#    'nevals': 106,
#    'std': array([[43437.703]], dtype=float32)},
#   {'avg': array([[14617.897]], dtype=float32),
#    'gen': 16,
#    'max': 99999.0,
#    'min': array([[5111.628]], dtype=float32),
#    'nevals': 111,
#    'std': array([[28460.482]], dtype=float32)},
#   {'avg': array([[7959.2544]], dtype=float32),
#    'gen': 17,
#    'max': 99999.0,
#    'min': array([[5111.628]], dtype=float32),
#    'nevals': 113,
#    'std': array([[16186.397]], dtype=float32)},
#   {'avg': array([[7958.247]], dtype=float32),
#    'gen': 18,
#    'max': 99999.0,
#    'min': array([[5111.628]], dtype=float32),
#    'nevals': 103,
#    'std': array([[16186.565]], dtype=float32)},
#   {'avg': array([[9855.994]], dtype=float32),
#    'gen': 19,
#    'max': 99999.0,
#    'min': array([[5111.628]], dtype=float32),
#    'nevals': 116,
#    'std': array([[20680.227]], dtype=float32)},
#   {'avg': array([[7009.373]], dtype=float32),
#    'gen': 20,
#    'max': 99999.0,
#    'min': array([[5111.628]], dtype=float32),
#    'nevals': 100,
#    'std': array([[13284.221]], dtype=float32)},
#   {'avg': array([[6534.936]], dtype=float32),
#    'gen': 21,
#    'max': 99999.0,
#    'min': array([[5111.628]], dtype=float32),
#    'nevals': 126,
#    'std': array([[11533.783]], dtype=float32)},
#   {'avg': array([[10804.875]], dtype=float32),
#    'gen': 22,
#    'max': 99999.0,
#    'min': array([[5111.628]], dtype=float32),
#    'nevals': 102,
#    'std': array([[22534.502]], dtype=float32)},
#   {'avg': array([[7483.81]], dtype=float32),
#    'gen': 23,
#    'max': 99999.0,
#    'min': array([[5111.628]], dtype=float32),
#    'nevals': 98,
#    'std': array([[14814.297]], dtype=float32)},
#   {'avg': array([[7958.247]], dtype=float32),
#    'gen': 24,
#    'max': 99999.0,
#    'min': array([[5111.628]], dtype=float32),
#    'nevals': 100,
#    'std': array([[16186.552]], dtype=float32)},
#   {'avg': array([[7958.246]], dtype=float32),
#    'gen': 25,
#    'max': 99999.0,
#    'min': array([[5111.628]], dtype=float32),
#    'nevals': 117,
#    'std': array([[16186.557]], dtype=float32)},
#   {'avg': array([[7958.246]], dtype=float32),
#    'gen': 26,
#    'max': 99999.0,
#    'min': array([[5111.628]], dtype=float32),
#    'nevals': 104,
#    'std': array([[16186.549]], dtype=float32)},
#   {'avg': array([[9381.558]], dtype=float32),
#    'gen': 27,
#    'max': 99999.0,
#    'min': array([[5111.628]], dtype=float32),
#    'nevals': 114,
#    'std': array([[19670.533]], dtype=float32)},
#   {'avg': array([[6534.936]], dtype=float32),
#    'gen': 28,
#    'max': 99999.0,
#    'min': array([[5111.628]], dtype=float32),
#    'nevals': 117,
#    'std': array([[11533.785]], dtype=float32)},
#   {'avg': array([[7483.81]], dtype=float32),
#    'gen': 29,
#    'max': 99999.0,
#    'min': array([[5111.628]], dtype=float32),
#    'nevals': 132,
#    'std': array([[14814.3]], dtype=float32)},
#   {'avg': array([[8432.684]], dtype=float32),
#    'gen': 30,
#    'max': 99999.0,
#    'min': array([[5111.628]], dtype=float32),
#    'nevals': 125,
#    'std': array([[17438.389]], dtype=float32)}],
#  <deap.tools.support.HallOfFame at 0x7f62e9a6f668>)

# %%
best_ind = tools.selBest(pop, 1)[0]
print("Best individual is {} and its time is {} seg".format(list(best_ind),
             float(best_ind.fitness.values[0])))
# Out:
# Best individual is [4, 2, 0, 7, 3, 6, 1, 5] and its time is 5111.6279296875 seg
